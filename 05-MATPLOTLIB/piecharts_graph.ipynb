# %%
import matplotlib.pyplot as plt

regions=['North','South','West','East']
revenue=[17,24,35,66]

plt.pie(revenue, labels=regions, autopct='%1.1f%%', colors=['Red','Blue','Green','gold'])
plt.title('PIE CHART')
plt.show()
