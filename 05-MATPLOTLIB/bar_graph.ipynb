# %%
import matplotlib.pyplot as plt

product=['A','B','C','D']
sales=[100,200,300,400]


plt.bar(product,sales,color='Red')
plt.xlabel('product')
plt.ylabel('Sales')
plt.title('BAR GRAPH')
plt.show()
