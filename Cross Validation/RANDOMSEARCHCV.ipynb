# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('iris')

# %%
X=df.drop('species',axis=1)
Y=df['species']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train_scaled=sc.fit_transform(X_train)
X_test_scaled=sc.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV
classifier=RandomizedSearchCV((model),{
    'n_neighbors': [2, 3, 5, 7, 9,10,12,15],
    'weights': ['uniform', 'distance',],
    'metric': ['euclidean', 'manhattan','cityblock']
},n_iter=10,cv=5,scoring='accuracy')

# %%
classifier.fit(X_train_scaled,Y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(),
#                    param_distributions={'metric': ['euclidean', 'manhattan',
#                                                    'cityblock'],
#                                         'n_neighbors': [2, 3, 5, 7, 9, 10, 12,
#                                                         15],
#                                         'weights': ['uniform', 'distance']},
#                    scoring='accuracy')

# %%
print("Best KNN Parameters:")
print(classifier.best_params_)

print("Best CV Score:")
print(classifier.best_score_)
# Out:
# Best KNN Parameters:
# {'weights': 'distance', 'n_neighbors': 9, 'metric': 'cityblock'}
# Best CV Score:
# 0.93

# %%
best_knn = classifier.best_estimator_

# %%
y_pred_knn = best_knn.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score
knn_accuracy = accuracy_score(Y_test, y_pred_knn)

print("KNN Test Accuracy:")
print(knn_accuracy)
# Out:
# KNN Test Accuracy:
# 0.98

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results[["param_metric","param_n_neighbors","param_weights","mean_test_score"]]
# Out:
#   param_metric  param_n_neighbors param_weights  mean_test_score
# 0    euclidean                  2      distance             0.92
# 1    cityblock                  9      distance             0.93
# 2    cityblock                  2      distance             0.92
# 3    cityblock                  3       uniform             0.92
# 4    euclidean                 15      distance             0.91
# 5    cityblock                  5       uniform             0.92
# 6    cityblock                 15      distance             0.91
# 7    euclidean                  9      distance             0.93
# 8    cityblock                 12       uniform             0.92
# 9    euclidean                  3       uniform             0.93
